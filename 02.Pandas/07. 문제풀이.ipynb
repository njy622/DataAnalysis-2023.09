# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ![Alt text](image.png)

# %%
import seaborn as sns
titanic = sns.load_dataset('titanic')
titanic.tail(3)
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked  class  \
# 888         0       3  female   NaN      1      2  23.45        S  Third
# 889         1       1    male  26.0      0      0  30.00        C  First
# 890         0       3    male  32.0      0      0   7.75        Q  Third
#
#        who  adult_male deck  embark_town alive  alone
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
# 20살 미만이면 성별에 관계없이 “미성년자”라고 한다.
# 20살 이상이면 나이에 따라 “청년”, “중년”, “장년”, “노년”을 구분하고 그 뒤에 성별을 나타내는 “남성”, “여성”을 붙인다.
dt1 = sns.load_dataset('titanic')  # 타이타닉 다시
bins = [1, 20, 30, 50, 70, 100]             # 1 < 미성년자 <= 20
labels = ["미성년자", "청년", "중년", "장년", "노년"]
dt1_bins = pd.cut(dt1.age, bins, labels=labels)
dt1_bins
# Out:
# 0        청년
# 1        중년
# 2        청년
# 3        중년
# 4        중년
#        ...
# 886      청년
# 887    미성년자
# 888     NaN
# 889      청년
# 890      중년
# Name: age, Length: 891, dtype: category
# Categories (5, object): ['미성년자' < '청년' < '중년' < '장년' < '노년']

# %%
dt1['category3'] = \
    dt1.apply(lambda x: pd.cut(dt1.age, bins, labels=labels).astype(str) + dt1.sex if dt1.x.age>=20 else '미성년자' )
dt1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# d:\Workspace\DataAnalysis\DataAnalysis-2023.09\02.Pandas\07. 문제풀이.ipynb 셀 5 line 2
#       <a href='vscode-notebook-cell:/d%3A/Workspace/DataAnalysis/DataAnalysis-2023.09/02.Pandas/07.%20%EB%AC%B8%EC%A0%9C%ED%92%80%EC%9D%B4.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> dt1['category3'] = \
# ----> <a href='vscode-notebook-cell:/d%3A/Workspace/DataAnalysis/DataAnalysis-2023.09/02.Pandas/07.%20%EB%AC%B8%EC%A0%9C%ED%92%80%EC%9D%B4.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a>     dt1.apply(lambda x: pd.cut(dt1.age, bins, labels=labels).astype(str) + dt1.sex if dt1.x.age>=20 else '미성년자' )
#       <a href='vscode-notebook-cell:/d%3A/Workspace/DataAnalysis/DataAnalysis-2023.09/02.Pandas/07.%20%EB%AC%B8%EC%A0%9C%ED%92%80%EC%9D%B4.ipynb#W4sZmlsZQ%3D%3D?line=2'>3</a> dt1
#
# File c:\Users\JIYEONGNAM\anaconda3\Lib\site-packages\pandas\core\frame.py:9568, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    9557 from pandas.core.apply import frame_apply
#    9559 op = frame_apply(
#    9560     self,
#    9561     func=func,
#    (...)
#    9566     kwargs=kwargs,
#    9567 )
# -> 9568 return op.apply().__finalize__(self, method="apply")
#
# File c:\Users\JIYEONGNAM\anaconda3\Lib\site-packages\pandas\core\apply.py:764, in FrameApply.apply(self)
#     761 elif self.raw:
#     762     return self.apply_raw()
# --> 764 return self.apply_standard()
#
# File c:\Users\JIYEONGNAM\anaconda3\Lib\site-packages\pandas\core\apply.py:891, in FrameApply.apply_standard(self)
#     890 def apply_standard(self):
# --> 891     results, res_index = self.apply_series_generator()
#     893     # wrap results
#     894     return self.wrap_results(results, res_index)
#
# File c:\Users\JIYEONGNAM\anaconda3\Lib\site-packages\pandas\core\apply.py:907, in FrameApply.apply_series_generator(self)
#     904 with option_context("mode.chained_assignment", None):
#     905     for i, v in enumerate(series_gen):
#     906         # ignore SettingWithCopy here in case the user mutates
# --> 907         results[i] = self.f(v)
#     908         if isinstance(results[i], ABCSeries):
#     909             # If we have a view on v, we need to make a copy because
#     910             #  series_generator will swap out the underlying data
#     911             results[i] = results[i].copy(deep=False)
#
# d:\Workspace\DataAnalysis\DataAnalysis-2023.09\02.Pandas\07. 문제풀이.ipynb 셀 5 line 2
#       <a href='vscode-notebook-cell:/d%3A/Workspace/DataAnalysis/DataAnalysis-2023.09/02.Pandas/07.%20%EB%AC%B8%EC%A0%9C%ED%92%80%EC%9D%B4.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> dt1['category3'] = \
# ----> <a href='vscode-notebook-cell:/d%3A/Workspace/DataAnalysis/DataAnalysis-2023.09/02.Pandas/07.%20%EB%AC%B8%EC%A0%9C%ED%92%80%EC%9D%B4.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a>     dt1.apply(lambda x: pd.cut(dt1.age, bins, labels=labels).astype(str) + dt1.sex if dt1.x.age>=20 else '미성년자' )
#       <a href='vscode-notebook-cell:/d%3A/Workspace/DataAnalysis/DataAnalysis-2023.09/02.Pandas/07.%20%EB%AC%B8%EC%A0%9C%ED%92%80%EC%9D%B4.ipynb#W4sZmlsZQ%3D%3D?line=2'>3</a> dt1
#
# File c:\Users\JIYEONGNAM\anaconda3\Lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'x'

# %%
dt1['category3'] = \
    dt1.apply(lambda x:\
    (pd.cut(dt1.age, bins, labels=labels).astype(str) + dt1.sex)
    if pd.cut(dt1.age, bins, labels=labels).astype(str)[x] != '미성년자'
    else '미성년자')
dt
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\Workspace\DataAnalysis\DataAnalysis-2023.09\02.Pandas\07. 문제풀이.ipynb Cell 6 line 2
#       <a href='vscode-notebook-cell:/d%3A/Workspace/DataAnalysis/DataAnalysis-2023.09/02.Pandas/07.%20%EB%AC%B8%EC%A0%9C%ED%92%80%EC%9D%B4.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> dt1['category3'] = \
# ----> <a href='vscode-notebook-cell:/d%3A/Workspace/DataAnalysis/DataAnalysis-2023.09/02.Pandas/07.%20%EB%AC%B8%EC%A0%9C%ED%92%80%EC%9D%B4.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a>     dt1.apply(lambda x:\
#       <a href='vscode-notebook-cell:/d%3A/Workspace/DataAnalysis/DataAnalysis-2023.09/02.Pandas/07.%20%EB%AC%B8%EC%A0%9C%ED%92%80%EC%9D%B4.ipynb#W5sZmlsZQ%3D%3D?line=2'>3</a>     (pd.cut(dt1.age, bins, labels=labels).astype(str) + dt1.sex)
#       <a href='vscode-notebook-cell:/d%3A/Workspace/DataAnalysis/DataAnalysis-2023.09/02.Pandas/07.%20%EB%AC%B8%EC%A0%9C%ED%92%80%EC%9D%B4.ipynb#W5sZmlsZQ%3D%3D?line=3'>4</a>     if pd.cut(dt1.age, bins, labels=labels).astype(str)[x] != '미성년자'
#       <a href='vscode-notebook-cell:/d%3A/Workspace/DataAnalysis/DataAnalysis-2023.09/02.Pandas/07.%20%EB%AC%B8%EC%A0%9C%ED%92%80%EC%9D%B4.ipynb#W5sZmlsZQ%3D%3D?line=4'>5</a>     else '미성년자')
#       <a href='vscode-notebook-cell:/d%3A/Workspace/DataAnalysis/DataAnalysis-2023.09/02.Pandas/07.%20%EB%AC%B8%EC%A0%9C%ED%92%80%EC%9D%B4.ipynb#W5sZmlsZQ%3D%3D?line=5'>6</a> dt
#
# File c:\Users\JIYEONGNAM\anaconda3\Lib\site-packages\pandas\core\frame.py:9568, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    9557 from pandas.core.apply import frame_apply
#    9559 op = frame_apply(
#    9560     self,
#    9561     func=func,
#    (...)
#    9566     kwargs=kwargs,
#    9567 )
# -> 9568 return op.apply().__finalize__(self, method="apply")
#
# File c:\Users\JIYEONGNAM\anaconda3\Lib\site-packages\pandas\core\apply.py:764, in FrameApply.apply(self)
#     761 elif self.raw:
#     762     return self.apply_raw()
# --> 764 return self.apply_standard()
#
# File c:\Users\JIYEONGNAM\anaconda3\Lib\site-packages\pandas\core\apply.py:891, in FrameApply.apply_standard(self)
#     890 def apply_standard(self):
# --> 891     results, res_index = self.apply_series_generator()
#     893     # wrap results
#     894     return self.wrap_results(results, res_index)
#
# File c:\Users\JIYEONGNAM\anaconda3\Lib\site-packages\pandas\core\apply.py:907, in FrameApply.apply_series_generator(self)
#     904 with option_context("mode.chained_assignment", None):
#     905     for i, v in enumerate(series_gen):
#     906         # ignore SettingWithCopy here in case the user mutates
# --> 907         results[i] = self.f(v)
#     908         if isinstance(results[i], ABCSeries):
#     909             # If we have a view on v, we need to make a copy because
#     910             #  series_generator will swap out the underlying data
#     911             results[i] = results[i].copy(deep=False)
#
# d:\Workspace\DataAnalysis\DataAnalysis-2023.09\02.Pandas\07. 문제풀이.ipynb Cell 6 line 4
#       <a href='vscode-notebook-cell:/d%3A/Workspace/DataAnalysis/DataAnalysis-2023.09/02.Pandas/07.%20%EB%AC%B8%EC%A0%9C%ED%92%80%EC%9D%B4.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> dt1['category3'] = \
#       <a href='vscode-notebook-cell:/d%3A/Workspace/DataAnalysis/DataAnalysis-2023.09/02.Pandas/07.%20%EB%AC%B8%EC%A0%9C%ED%92%80%EC%9D%B4.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a>     dt1.apply(lambda x:\
#       <a href='vscode-notebook-cell:/d%3A/Workspace/DataAnalysis/DataAnalysis-2023.09/02.Pandas/07.%20%EB%AC%B8%EC%A0%9C%ED%92%80%EC%9D%B4.ipynb#W5sZmlsZQ%3D%3D?line=2'>3</a>     (pd.cut(dt1.age, bins, labels=labels).astype(str) + dt1.sex)
# ----> <a href='vscode-notebook-cell:/d%3A/Workspace/DataAnalysis/DataAnalysis-2023.09/02.Pandas/07.%20%EB%AC%B8%EC%A0%9C%ED%92%80%EC%9D%B4.ipynb#W5sZmlsZQ%3D%3D?line=3'>4</a>     if pd.cut(dt1.age, bins, labels=labels).astype(str)[x] != '미성년자'
#       <a href='vscode-notebook-cell:/d%3A/Workspace/DataAnalysis/DataAnalysis-2023.09/02.Pandas/07.%20%EB%AC%B8%EC%A0%9C%ED%92%80%EC%9D%B4.ipynb#W5sZmlsZQ%3D%3D?line=4'>5</a>     else '미성년자')
#       <a href='vscode-notebook-cell:/d%3A/Workspace/DataAnalysis/DataAnalysis-2023.09/02.Pandas/07.%20%EB%AC%B8%EC%A0%9C%ED%92%80%EC%9D%B4.ipynb#W5sZmlsZQ%3D%3D?line=5'>6</a> dt
#
# File c:\Users\JIYEONGNAM\anaconda3\Lib\site-packages\pandas\core\generic.py:1527, in NDFrame.__nonzero__(self)
#    1525 @final
#    1526 def __nonzero__(self) -> NoReturn:
# -> 1527     raise ValueError(
#    1528         f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529         "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1530     )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %% [markdown]
# ![Alt text](image-1.png)

# %%
#학생 이름을 나타내는 열을 포함시키지 않고 데이터프레임 df_score1 을 
# 생성한 후, df_score1.index 속성에 학생 이름을 나타내는 열을 지정하여 
# 인덱스를 지정한다.  reset_index 명령으로 이 인덱스 열을 명령으로 
# 일반 데이터열로 바꾸여 데이터프레임 df_score2을 만든다.

# %%
#학생 이름을 나타내는 열이 일반 데이터 열을 포함하는 데이터프레임 
#df_score2에 set_index 명령을 적용하여 다시 학생 이름을 나타내는 열을
# 인덱스로 변경한다.

# %% [markdown]
# 서울시 자치구 연도별 방범용 CCTV 운영 현황_230630기준.csv <br>
# 해당 파일 숫자변환 => 구별 합계를 내시오

# %% [markdown]
# for col in cctv.columns:  <br>
# cctv[col]

# %%
cctv = pd.read_csv('data/서울시 자치구 연도별 방범용 CCTV 운영 현황_230630기준.csv', encoding='EUC-KR', index_col=0)
cctv
# Out:
#       구분  2015년  2016년  2017년  2018년  2019년  2020년  2021년  2022년   2023년
# 1    종로구    935  1,066  1,225  1,322  1,338  1,526   1573   1812   1,808
# 2     중구    363    565    838  1,174  1,234  1,482   1911   2026   2,026
# 3    용산구  1,398  1,689  1,831  1,888  1,986  2,131   2321   2531   2,647
# 4    성동구  1,089  1,328  2,103  2,390  2,697  3,162   3519   3627   3,643
# 5    광진구    638    657  1,112  1,586  2,233  2,375   3111   3370   3,359
# 6   동대문구  1,202  1,425  1,535  1,775  1,969  2,142   2471   2592   2,592
# 7    중랑구    751    898  1,047  1,203  2,250  3,165   3592   3856   3,856
# 8    성북구  1,035  1,534  1,940  2,542  2,895  3,081   3815   4014   4,129
# 9    강북구    608    840    841  1,159  1,656  2,337   2960   3184   3,184
# 10   도봉구    345    443    542    679    835    979   1684   1994   2,120
# 11   노원구    956  1,268  1,433  1,577  1,763  2,021   2171   2284   2,281
# 12   은평구  1,719  2,075  2,310  2,669  3,164  3,431   3822   4103   4,103
# 13  서대문구    952  1,179  1,525  1,764  2,100  2,499   2591   2928   3,006
# 14   마포구    623    970  1,328  1,703  2,011  2,268   2372   2500   2,500
# 15   양천구  1,898  2,026  2,367  2,655  2,928  3,136   3393   3627   3,609
# 16   강서구    801    960  1,164  1,386  1,858  2,346   2637   3151   3,209
# 17   구로구  1,407  1,719  2,231  2,819  3,074  3,455   3842   4013   4,122
# 18   금천구    990  1,090  1,181  1,563  1,894  2,247   2276   2498   2,730
# 19  영등포구    904  1,140  1,429  2,055  2,093  3,250   3508   3896   3,964
# 20   동작구    961  1,200  1,471  1,690  1,904  2,155   2181   2404   2,402
# 21   관악구  1,496  2,048  2,611  3,247  3,800  4,071   3390   4029   4,245
# 22   서초구  1,548  1,785  2,169  2,582  2,938  3,175   3442   3180  3,180
# 23   강남구  2,319  3,447  4,232  4,834  5,459  5,796   6143   6495   6,495
# 24   송파구    713    798    913  1,364  2,052  2,372   2520   2805   2,821
# 25   강동구    670    863  1,134  1,596  1,871  2,475   2720   3086   3,088

# %%
cctv.columns[1:]
# Out:
# Index(['2015년', '2016년', '2017년', '2018년', '2019년', '2020년', '2021년', '2022년',
#        '2023년'],
#       dtype='object')

# %%
cctv.values[:22, 1:], cctv.values[23:25, 1:]
# Out:
# (array([['935', '1,066', '1,225', '1,322', '1,338', '1,526', 1573, 1812,
#          '1,808'],
#         ['363', '565', '838', '1,174', '1,234', '1,482', 1911, 2026,
#          '2,026'],
#         ['1,398', '1,689', '1,831', '1,888', '1,986', '2,131', 2321, 2531,
#          '2,647'],
#         ['1,089', '1,328', '2,103', '2,390', '2,697', '3,162', 3519, 3627,
#          '3,643'],
#         ['638', '657', '1,112', '1,586', '2,233', '2,375', 3111, 3370,
#          '3,359'],
#         ['1,202', '1,425', '1,535', '1,775', '1,969', '2,142', 2471, 2592,
#          '2,592'],
#         ['751', '898', '1,047', '1,203', '2,250', '3,165', 3592, 3856,
#          '3,856'],
#         ['1,035', '1,534', '1,940', '2,542', '2,895', '3,081', 3815, 4014,
#          '4,129'],
#         ['608', '840', '841', '1,159', '1,656', '2,337', 2960, 3184,
#          '3,184'],
#         ['345', '443', '542', '679', '835', '979', 1684, 1994, '2,120'],
#         ['956', '1,268', '1,433', '1,577', '1,763', '2,021', 2171, 2284,
#          '2,281'],
#         ['1,719', '2,075', '2,310', '2,669', '3,164', '3,431', 3822, 4103,
#          '4,103'],
#         ['952', '1,179', '1,525', '1,764', '2,100', '2,499', 2591, 2928,
#          '3,006'],
#         ['623', '970', '1,328', '1,703', '2,011', '2,268', 2372, 2500,
#          '2,500'],
#         ['1,898', '2,026', '2,367', '2,655', '2,928', '3,136', 3393, 3627,
#          '3,609'],
#         ['801', '960', '1,164', '1,386', '1,858', '2,346', 2637, 3151,
#          '3,209'],
#         ['1,407', '1,719', '2,231', '2,819', '3,074', '3,455', 3842, 4013,
#          '4,122'],
#         ['990', '1,090', '1,181', '1,563', '1,894', '2,247', 2276, 2498,
#          '2,730'],
#         ['904', '1,140', '1,429', '2,055', '2,093', '3,250', 3508, 3896,
#          '3,964'],
#         ['961', '1,200', '1,471', '1,690', '1,904', '2,155', 2181, 2404,
#          '2,402'],
#         ['1,496', '2,048', '2,611', '3,247', '3,800', '4,071', 3390, 4029,
#          '4,245'],
#         ['1,548', '1,785', '2,169', '2,582', '2,938', '3,175', 3442, 3180,
#          '3,180 ']], dtype=object),
#  array([['713', '798', '913', '1,364', '2,052', '2,372', 2520, 2805,
#          '2,821'],
#         ['670', '863', '1,134', '1,596', '1,871', '2,475', 2720, 3086,
#          '3,088']], dtype=object))

# %%
cctv1 = cctv['2015년'][:25].str.replace(',','').astype(int)
cctv1
# Out:
# 1      935
# 2      363
# 3     1398
# 4     1089
# 5      638
# 6     1202
# 7      751
# 8     1035
# 9      608
# 10     345
# 11     956
# 12    1719
# 13     952
# 14     623
# 15    1898
# 16     801
# 17    1407
# 18     990
# 19     904
# 20     961
# 21    1496
# 22    1548
# 23    2319
# 24     713
# 25     670
# Name: 2015년, dtype: int32

# %%
for col in cctv.columns[1:]:
    for i in range(len(cctv.columns)):
            print(cctv[col].apply(lambda x: int(x.replace(',',''))))
# Out:
# 1      935
# 2      363
# 3     1398
# 4     1089
# 5      638
# 6     1202
# 7      751
# 8     1035
# 9      608
# 10     345
# 11     956
# 12    1719
# 13     952
# 14     623
# 15    1898
# 16     801
# 17    1407
# 18     990
# 19     904
# 20     961
# 21    1496
# 22    1548
# 23    2319
# 24     713
# 25     670
# Name: 2015년, dtype: int64
# 1     1066
# 2      565
# 3     1689
# 4     1328
# 5      657
# 6     1425
# 7      898
# 8     1534
# 9      840
# 10     443
# 11    1268
# 12    2075
# 13    1179
# 14     970
# 15    2026
# 16     960
# 17    1719
# 18    1090
# 19    1140
# 20    1200
# 21    2048
# 22    1785
# 23    3447
# 24     798
# 25     863
# Name: 2016년, dtype: int64
# 1     1225
# 2      838
# 3     1831
# 4     2103
# 5     1112
# 6     1535
# 7     1047
# 8     1940
# 9      841
# 10     542
# 11    1433
# 12    2310
# 13    1525
# 14    1328
# 15    2367
# 16    1164
# 17    2231
# 18    1181
# 19    1429
# 20    1471
# 21    2611
# 22    2169
# 23    4232
# 24     913
# 25    1134
# Name: 2017년, dtype: int64
# 1     1322
# 2     1174
# 3     1888
# 4     2390
# 5     1586
# 6     1775
# 7     1203
# 8     2542
# 9     1159
# 10     679
# 11    1577
# 12    2669
# 13    1764
# 14    1703
# 15    2655
# 16    1386
# 17    2819
# 18    1563
# 19    2055
# 20    1690
# 21    3247
# 22    2582
# 23    4834
# 24    1364
# 25    1596
# Name: 2018년, dtype: int64
# 1     1338
# 2     1234
# 3     1986
# 4     2697
# 5     2233
# 6     1969
# 7     2250
# 8     2895
# 9     1656
# 10     835
# 11    1763
# 12    3164
# 13    2100
# 14    2011
# 15    2928
# 16    1858
# 17    3074
# 18    1894
# 19    2093
# 20    1904
# 21    3800
# 22    2938
# 23    5459
# 24    2052
# 25    1871
# Name: 2019년, dtype: int64
# 1     1526
# 2     1482
# 3     2131
# 4     3162
# 5     2375
# 6     2142
# 7     3165
# 8     3081
# 9     2337
# 10     979
# 11    2021
# 12    3431
# 13    2499
# 14    2268
# 15    3136
# 16    2346
# 17    3455
# 18    2247
# 19    3250
# 20    2155
# 21    4071
# 22    3175
# 23    5796
# 24    2372
# 25    2475
# Name: 2020년, dtype: int64
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# d:\Workspace\DataAnalysis\DataAnalysis-2023.09\02.Pandas\07. 문제풀이.ipynb 셀 16 line 2
#       <a href='vscode-notebook-cell:/d%3A/Workspace/DataAnalysis/DataAnalysis-2023.09/02.Pandas/07.%20%EB%AC%B8%EC%A0%9C%ED%92%80%EC%9D%B4.ipynb#X21sZmlsZQ%3D%3D?line=0'>1</a> for col in cctv.columns[1:]:
# ----> <a href='vscode-notebook-cell:/d%3A/Workspace/DataAnalysis/DataAnalysis-2023.09/02.Pandas/07.%20%EB%AC%B8%EC%A0%9C%ED%92%80%EC%9D%B4.ipynb#X21sZmlsZQ%3D%3D?line=1'>2</a>     print(cctv[col].apply(lambda x: int(x.replace(',',''))))
#
# File c:\Users\JIYEONGNAM\anaconda3\Lib\site-packages\pandas\core\series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
#    4666     **kwargs,
#    4667 ) -> DataFrame | Series:
#    4668     """
#    4669     Invoke function on values of Series.
#    4670
#    (...)
#    4769     dtype: float64
#    4770     """
# -> 4771     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File c:\Users\JIYEONGNAM\anaconda3\Lib\site-packages\pandas\core\apply.py:1123, in SeriesApply.apply(self)
#    1120     return self.apply_str()
#    1122 # self.f is Callable
# -> 1123 return self.apply_standard()
#
# File c:\Users\JIYEONGNAM\anaconda3\Lib\site-packages\pandas\core\apply.py:1174, in SeriesApply.apply_standard(self)
#    1172     else:
#    1173         values = obj.astype(object)._values
# -> 1174         mapped = lib.map_infer(
#    1175             values,
#    1176             f,
#    1177             convert=self.convert_dtype,
#    1178         )
#    1180 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1181     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1182     #  See also GH#25959 regarding EA support
#    1183     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File c:\Users\JIYEONGNAM\anaconda3\Lib\site-packages\pandas\_libs\lib.pyx:2924, in pandas._libs.lib.map_infer()
#
# d:\Workspace\DataAnalysis\DataAnalysis-2023.09\02.Pandas\07. 문제풀이.ipynb 셀 16 line 2
#       <a href='vscode-notebook-cell:/d%3A/Workspace/DataAnalysis/DataAnalysis-2023.09/02.Pandas/07.%20%EB%AC%B8%EC%A0%9C%ED%92%80%EC%9D%B4.ipynb#X21sZmlsZQ%3D%3D?line=0'>1</a> for col in cctv.columns[1:]:
# ----> <a href='vscode-notebook-cell:/d%3A/Workspace/DataAnalysis/DataAnalysis-2023.09/02.Pandas/07.%20%EB%AC%B8%EC%A0%9C%ED%92%80%EC%9D%B4.ipynb#X21sZmlsZQ%3D%3D?line=1'>2</a>     print(cctv[col].apply(lambda x: int(x.replace(',',''))))
#
# AttributeError: 'int' object has no attribute 'replace'

# %%
cctv.values[:25, 1:]
# Out:
# array([['935', '1,066', '1,225', '1,322', '1,338', '1,526', 1573, 1812,
#         '1,808'],
#        ['363', '565', '838', '1,174', '1,234', '1,482', 1911, 2026,
#         '2,026'],
#        ['1,398', '1,689', '1,831', '1,888', '1,986', '2,131', 2321, 2531,
#         '2,647'],
#        ['1,089', '1,328', '2,103', '2,390', '2,697', '3,162', 3519, 3627,
#         '3,643'],
#        ['638', '657', '1,112', '1,586', '2,233', '2,375', 3111, 3370,
#         '3,359'],
#        ['1,202', '1,425', '1,535', '1,775', '1,969', '2,142', 2471, 2592,
#         '2,592'],
#        ['751', '898', '1,047', '1,203', '2,250', '3,165', 3592, 3856,
#         '3,856'],
#        ['1,035', '1,534', '1,940', '2,542', '2,895', '3,081', 3815, 4014,
#         '4,129'],
#        ['608', '840', '841', '1,159', '1,656', '2,337', 2960, 3184,
#         '3,184'],
#        ['345', '443', '542', '679', '835', '979', 1684, 1994, '2,120'],
#        ['956', '1,268', '1,433', '1,577', '1,763', '2,021', 2171, 2284,
#         '2,281'],
#        ['1,719', '2,075', '2,310', '2,669', '3,164', '3,431', 3822, 4103,
#         '4,103'],
#        ['952', '1,179', '1,525', '1,764', '2,100', '2,499', 2591, 2928,
#         '3,006'],
#        ['623', '970', '1,328', '1,703', '2,011', '2,268', 2372, 2500,
#         '2,500'],
#        ['1,898', '2,026', '2,367', '2,655', '2,928', '3,136', 3393, 3627,
#         '3,609'],
#        ['801', '960', '1,164', '1,386', '1,858', '2,346', 2637, 3151,
#         '3,209'],
#        ['1,407', '1,719', '2,231', '2,819', '3,074', '3,455', 3842, 4013,
#         '4,122'],
#        ['990', '1,090', '1,181', '1,563', '1,894', '2,247', 2276, 2498,
#         '2,730'],
#        ['904', '1,140', '1,429', '2,055', '2,093', '3,250', 3508, 3896,
#         '3,964'],
#        ['961', '1,200', '1,471', '1,690', '1,904', '2,155', 2181, 2404,
#         '2,402'],
#        ['1,496', '2,048', '2,611', '3,247', '3,800', '4,071', 3390, 4029,
#         '4,245'],
#        ['1,548', '1,785', '2,169', '2,582', '2,938', '3,175', 3442, 3180,
#         '3,180 '],
#        ['2,319', '3,447', '4,232', '4,834', '5,459', '5,796', 6143, 6495,
#         '6,495'],
#        ['713', '798', '913', '1,364', '2,052', '2,372', 2520, 2805,
#         '2,821'],
#        ['670', '863', '1,134', '1,596', '1,871', '2,475', 2720, 3086,
#         '3,088']], dtype=object)

# %%
cctv['2015년'].apply(lambda x: x.replace(',',''))
# Out:
# 1      935
# 2      363
# 3     1398
# 4     1089
# 5      638
# 6     1202
# 7      751
# 8     1035
# 9      608
# 10     345
# 11     956
# 12    1719
# 13     952
# 14     623
# 15    1898
# 16     801
# 17    1407
# 18     990
# 19     904
# 20     961
# 21    1496
# 22    1548
# 23    2319
# 24     713
# 25     670
# Name: 2015년, dtype: object

# %%
for col in cctv.columns[1:]:
    if (cctv[col].dtype) == 'object':
        cctv[col] = cctv[col].apply(lambda x: int(x.replace(',', '')))
    elif (cctv[col].dtype) == 'int32' and (cctv[col].dtype) == 'int64':
        cctv[col] = cctv[col]

cctv[col]
# Out:
# 1     1808
# 2     2026
# 3     2647
# 4     3643
# 5     3359
# 6     2592
# 7     3856
# 8     4129
# 9     3184
# 10    2120
# 11    2281
# 12    4103
# 13    3006
# 14    2500
# 15    3609
# 16    3209
# 17    4122
# 18    2730
# 19    3964
# 20    2402
# 21    4245
# 22    3180
# 23    6495
# 24    2821
# 25    3088
# Name: 2023년, dtype: int64

# %%
cctv
# Out:
#       구분  2015년  2016년  2017년  2018년  2019년  2020년  2021년  2022년  2023년
# 1    종로구    935   1066   1225   1322   1338   1526   1573   1812   1808
# 2     중구    363    565    838   1174   1234   1482   1911   2026   2026
# 3    용산구   1398   1689   1831   1888   1986   2131   2321   2531   2647
# 4    성동구   1089   1328   2103   2390   2697   3162   3519   3627   3643
# 5    광진구    638    657   1112   1586   2233   2375   3111   3370   3359
# 6   동대문구   1202   1425   1535   1775   1969   2142   2471   2592   2592
# 7    중랑구    751    898   1047   1203   2250   3165   3592   3856   3856
# 8    성북구   1035   1534   1940   2542   2895   3081   3815   4014   4129
# 9    강북구    608    840    841   1159   1656   2337   2960   3184   3184
# 10   도봉구    345    443    542    679    835    979   1684   1994   2120
# 11   노원구    956   1268   1433   1577   1763   2021   2171   2284   2281
# 12   은평구   1719   2075   2310   2669   3164   3431   3822   4103   4103
# 13  서대문구    952   1179   1525   1764   2100   2499   2591   2928   3006
# 14   마포구    623    970   1328   1703   2011   2268   2372   2500   2500
# 15   양천구   1898   2026   2367   2655   2928   3136   3393   3627   3609
# 16   강서구    801    960   1164   1386   1858   2346   2637   3151   3209
# 17   구로구   1407   1719   2231   2819   3074   3455   3842   4013   4122
# 18   금천구    990   1090   1181   1563   1894   2247   2276   2498   2730
# 19  영등포구    904   1140   1429   2055   2093   3250   3508   3896   3964
# 20   동작구    961   1200   1471   1690   1904   2155   2181   2404   2402
# 21   관악구   1496   2048   2611   3247   3800   4071   3390   4029   4245
# 22   서초구   1548   1785   2169   2582   2938   3175   3442   3180   3180
# 23   강남구   2319   3447   4232   4834   5459   5796   6143   6495   6495
# 24   송파구    713    798    913   1364   2052   2372   2520   2805   2821
# 25   강동구    670    863   1134   1596   1871   2475   2720   3086   3088

# %%
cctv['구별 합계'] = cctv.sum(axis=1)
cctv
# Out:
# C:\Users\JIYEONGNAM\AppData\Local\Temp\ipykernel_7692\2302271069.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   cctv['구별 합계'] = cctv.sum(axis=1)
#       구분  2015년  2016년  2017년  2018년  2019년  2020년  2021년  2022년  2023년  구별 합계
# 1    종로구    935   1066   1225   1322   1338   1526   1573   1812   1808  12605
# 2     중구    363    565    838   1174   1234   1482   1911   2026   2026  11619
# 3    용산구   1398   1689   1831   1888   1986   2131   2321   2531   2647  18422
# 4    성동구   1089   1328   2103   2390   2697   3162   3519   3627   3643  23558
# 5    광진구    638    657   1112   1586   2233   2375   3111   3370   3359  18441
# 6   동대문구   1202   1425   1535   1775   1969   2142   2471   2592   2592  17703
# 7    중랑구    751    898   1047   1203   2250   3165   3592   3856   3856  20618
# 8    성북구   1035   1534   1940   2542   2895   3081   3815   4014   4129  24985
# 9    강북구    608    840    841   1159   1656   2337   2960   3184   3184  16769
# 10   도봉구    345    443    542    679    835    979   1684   1994   2120   9621
# 11   노원구    956   1268   1433   1577   1763   2021   2171   2284   2281  15754
# 12   은평구   1719   2075   2310   2669   3164   3431   3822   4103   4103  27396
# 13  서대문구    952   1179   1525   1764   2100   2499   2591   2928   3006  18544
# 14   마포구    623    970   1328   1703   2011   2268   2372   2500   2500  16275
# 15   양천구   1898   2026   2367   2655   2928   3136   3393   3627   3609  25639
# 16   강서구    801    960   1164   1386   1858   2346   2637   3151   3209  17512
# 17   구로구   1407   1719   2231   2819   3074   3455   3842   4013   4122  26682
# 18   금천구    990   1090   1181   1563   1894   2247   2276   2498   2730  16469
# 19  영등포구    904   1140   1429   2055   2093   3250   3508   3896   3964  22239
# 20   동작구    961   1200   1471   1690   1904   2155   2181   2404   2402  16368
# 21   관악구   1496   2048   2611   3247   3800   4071   3390   4029   4245  28937
# 22   서초구   1548   1785   2169   2582   2938   3175   3442   3180   3180  23999
# 23   강남구   2319   3447   4232   4834   5459   5796   6143   6495   6495  45220
# 24   송파구    713    798    913   1364   2052   2372   2520   2805   2821  16358
# 25   강동구    670    863   1134   1596   1871   2475   2720   3086   3088  17503
