# %% [markdown]
# ### 2.10 서울시 구별 CCTV 현황분석
# - 서울시 자치구 연도별 CCTV 설치 현황
# - 서울시 주민등록인구(구별) 통계

# %% [markdown]
# - 컬럼
#     - CCTV댓수: 2015년~ 2022년 계
#     - 최근 증가율: (2020 ~ 2022) / 총대수 *100
#     - 인구수: 2023 1/4분기 자료
#     - 내국인:
#     - 외국인:
#     - 고령자:
#     - 외국인비율:
#     - 고령자비율:
#
# - 인덱스
#     - 각 구

# %%
import numpy as np
import pandas as pd

# %%
# CCTV 갯수 : 2015년 ~ 2022년 계
cctv = pd.read_csv('data/서울시 자치구 년도별 CCTV 설치 현황_230630기준.csv', 
            encoding='EUC-KR', index_col='구분', thousands=',')
cctv.head(3)
# Out:
#      Unnamed: 0     총계  2014년 이전  2014년  2015년  2016년  2017년  2018년  2019년  \
# 구분
# 계           NaN  92991    5896.0   3927   6416   8812  11598  10887  13083
# 종로구         1.0   1966     553.0    103    160    130    144    150     67
# 중 구         2.0   2584     217.0     77    236    240    372    386    155
#
#      2020년  2021년  2022년   2023년
# 구분
# 계    11803   9396   9302  1871.0
# 종로구    233     88    207   131.0
# 중 구    361    403    137     0.0

# %%
cctv.drop(columns=['Unnamed: 0','총계', '2023년'], inplace=True)
cctv.drop(['계'], inplace=True)            # '계' 행 지우기
cctv.head(3)
# Out:
#      2014년 이전  2014년  2015년  2016년  2017년  2018년  2019년  2020년  2021년  2022년
# 구분
# 종로구     553.0    103    160    130    144    150     67    233     88    207
# 중 구     217.0     77    236    240    372    386    155    361    403    137
# 용산구      87.0     68     83    295    491    115    322    623    422    464

# %%
# 결측치가 있는지 확인
cctv['2014년 이전'].isna().sum()
# Out:
# 1

# %%
# 결측치를 0으로 대체하고, 타입을 정수로 변경
cctv = cctv.fillna(0).astype(int)
cctv
# Out:
#       2014년 이전  2014년  2015년  2016년  2017년  2018년  2019년  2020년  2021년  2022년
# 구분
# 종로구        553    103    160    130    144    150     67    233     88    207
# 중 구        217     77    236    240    372    386    155    361    403    137
# 용산구         87     68     83    295    491    115    322    623    422    464
# 성동구        157    110    366    281    942    457    643    485    367    232
# 광진구        130    176     95     40    666    460    712    190    738    273
# 동대문구         3      5     72    774    702    201    218    229    229    317
# 중랑구        555    104    145    153    170    215   1074    976    507    294
# 성북구        318    229    322    594    811    867    714    253    407    338
# 강북구         21     16     68    210      4    375    963    569    298    797
# 도봉구         98     54     27     91    116    183    195    179    592    591
# 노원구        238     75    509    329    171    216    324    387    215    144
# ...

# %%
# 결측치가 있는지 다시 확인
cctv['2014년 이전'].isna().sum()
# Out:
# 0

# %%
cctv['CCTV댓수'] = cctv.sum(axis=1)
cctv.head(3)
# Out:
#      2014년 이전  2014년  2015년  2016년  2017년  2018년  2019년  2020년  2021년  2022년  \
# 구분
# 종로구       553    103    160    130    144    150     67    233     88    207
# 중 구       217     77    236    240    372    386    155    361    403    137
# 용산구        87     68     83    295    491    115    322    623    422    464
#
#      CCTV댓수
# 구분
# 종로구    1835
# 중 구    2584
# 용산구    2970

# %%
cctv['최근증가율'] = (cctv.loc[:,'2020년':'2022년'].sum(axis=1) / cctv['CCTV댓수'] * 100).round(2)
cctv.head(3)
# Out:
#      2014년 이전  2014년  2015년  2016년  2017년  2018년  2019년  2020년  2021년  2022년  \
# 구분
# 종로구       553    103    160    130    144    150     67    233     88    207
# 중 구       217     77    236    240    372    386    155    361    403    137
# 용산구        87     68     83    295    491    115    322    623    422    464
#
#      CCTV댓수  최근증가율
# 구분
# 종로구    1835  28.77
# 중 구    2584  34.87
# 용산구    2970  50.81

# %%
cctv.drop(columns= ['2014년 이전']+'2014년 2015년	2016년	2017년	2018년	2019년	2020년	2021년	2022년'.split(),
                     inplace=True)
cctv.head()
# Out:
#      CCTV댓수  최근증가율
# 구분
# 종로구    1835  28.77
# 중 구    2584  34.87
# 용산구    2970  50.81
# 성동구    4040  26.83
# 광진구    3480  34.51

# %%
# '중 구'의 blank 없애기
cctv.index = cctv.index.str.replace(' ', '')
cctv.index[1]
# Out:
# '중구'

# %% [markdown]
# ## 선생님 풀이
# ### 1. CCTV데이터

# %%
# CCTV 갯수 : 2015년 ~ 2022년 계
cctv = pd.read_csv('data/서울시 자치구 연도별 방범용 CCTV 운영 현황_230630기준.csv', 
            encoding='EUC-KR', index_col='구분', thousands=',')

cctv.head(3)
# Out:
#      Unnamed: 0  2015년  2016년  2017년  2018년  2019년  2020년  2021년  2022년  2023년
# 구분
# 종로구           1    935   1066   1225   1322   1338   1526   1573   1812   1808
# 중구            2    363    565    838   1174   1234   1482   1911   2026   2026
# 용산구           3   1398   1689   1831   1888   1986   2131   2321   2531   2647

# %%
cctv.drop(columns=['Unnamed: 0', '2023년'], inplace=True)
cctv.head(3)
# Out:
#      2015년  2016년  2017년  2018년  2019년  2020년  2021년  2022년
# 구분
# 종로구    935   1066   1225   1322   1338   1526   1573   1812
# 중구     363    565    838   1174   1234   1482   1911   2026
# 용산구   1398   1689   1831   1888   1986   2131   2321   2531

# %%
cctv['CCTV댓수'] = cctv.sum(axis=1)
cctv.head(3)
# Out:
#      2015년  2016년  2017년  2018년  2019년  2020년  2021년  2022년  CCTV댓수
# 구분
# 종로구    935   1066   1225   1322   1338   1526   1573   1812   10797
# 중구     363    565    838   1174   1234   1482   1911   2026    9593
# 용산구   1398   1689   1831   1888   1986   2131   2321   2531   15775

# %%
cctv['최근증가율'] = ((cctv['2020년']+ cctv['2021년'] + cctv['2022년']) / cctv['CCTV댓수'] * 100).round(2)
cctv.head(3)
# Out:
#      2015년  2016년  2017년  2018년  2019년  2020년  2021년  2022년  CCTV댓수  최근증가율
# 구분
# 종로구    935   1066   1225   1322   1338   1526   1573   1812   10797  45.48
# 중구     363    565    838   1174   1234   1482   1911   2026    9593  56.49
# 용산구   1398   1689   1831   1888   1986   2131   2321   2531   15775  44.27

# %%
## 위의 방법을 슬라이싱방식으로 
cctv['최근증가율'] = (cctv.iloc[:, 5:-2].sum(axis=1) / cctv['CCTV댓수'] *100).round(2)
cctv.head(3)
# Out:
#      2015년  2016년  2017년  2018년  2019년  2020년  2021년  2022년  CCTV댓수  최근증가율
# 구분
# 종로구    935   1066   1225   1322   1338   1526   1573   1812   10797  45.48
# 중구     363    565    838   1174   1234   1482   1911   2026    9593  56.49
# 용산구   1398   1689   1831   1888   1986   2131   2321   2531   15775  44.27

# %%
cctv.drop(columns='2015년	2016년	2017년	2018년	2019년	2020년	2021년	2022년'.split(), inplace=True)
cctv.head(3)
# Out:
#      CCTV댓수  최근증가율
# 구분
# 종로구   10797  45.48
# 중구     9593  56.49
# 용산구   15775  44.27

# %% [markdown]
# ### 2. 서울시 인구데이터 정리하기

# %%
person = pd.read_csv('data/서울시 구별 주민등록인구.csv',
                    thousands=',',  skiprows=1 )
person.drop(columns=['세대당인구 (명)','동별(1)','세대 (세대)','세대 (세대).1','계 (명).1','한국인 (명).1','등록외국인 (명).1','인구밀도'], inplace=True)

person
# Out:
#    동별(2)    계 (명)  한국인 (명)  등록외국인 (명)  65세이상고령자 (명)
# 0     소계  9668008  9426404     241604       1690961
# 1    종로구   152212   141060      11152         28265
# 2     중구   131390   120963      10427         25353
# 3    용산구   232482   217756      14726         39478
# 4    성동구   287240   280240       7000         48238
# 5    광진구   350925   336801      14124         54854
# 6   동대문구   354884   337574      17310         65154
# 7    중랑구   389928   385003       4925         76116
# 8    성북구   441855   430100      11755         78427
# 9    강북구   296934   292762       4172         67056
# 10   도봉구   312858   310509       2349         68114
# 11   노원구   506989   502515       4474         93279
# 12   은평구   468766   464871       3895         90556
# 13  서대문구   321966   308437      13529         56785
# 14   마포구   376542   365570      10972         56582
# 15   양천구   442345   439219       3126         73522
# 16   강서구   573711   568287       5424         98659
# ...

# %%
person.columns = ['구별', '인구수', '내국인', '외국인','고령자']
person
# Out:
#       구별      인구수      내국인     외국인      고령자
# 0     소계  9668008  9426404  241604  1690961
# 1    종로구   152212   141060   11152    28265
# 2     중구   131390   120963   10427    25353
# 3    용산구   232482   217756   14726    39478
# 4    성동구   287240   280240    7000    48238
# 5    광진구   350925   336801   14124    54854
# 6   동대문구   354884   337574   17310    65154
# 7    중랑구   389928   385003    4925    76116
# 8    성북구   441855   430100   11755    78427
# 9    강북구   296934   292762    4172    67056
# 10   도봉구   312858   310509    2349    68114
# 11   노원구   506989   502515    4474    93279
# 12   은평구   468766   464871    3895    90556
# 13  서대문구   321966   308437   13529    56785
# 14   마포구   376542   365570   10972    56582
# 15   양천구   442345   439219    3126    73522
# 16   강서구   573711   568287    5424    98659
# 17   구로구   417983   395183   22800    77259
# 18   금천구   242467   229307   13160    43772
# 19  영등포구   398999   376614   22385    66014
# ...

# %%
# 첫번째 행 지우기
person.drop([0], inplace=True)
person
# Out:
#       구별     인구수     내국인    외국인     고령자
# 1    종로구  152212  141060  11152   28265
# 2     중구  131390  120963  10427   25353
# 3    용산구  232482  217756  14726   39478
# 4    성동구  287240  280240   7000   48238
# 5    광진구  350925  336801  14124   54854
# 6   동대문구  354884  337574  17310   65154
# 7    중랑구  389928  385003   4925   76116
# 8    성북구  441855  430100  11755   78427
# 9    강북구  296934  292762   4172   67056
# 10   도봉구  312858  310509   2349   68114
# 11   노원구  506989  502515   4474   93279
# 12   은평구  468766  464871   3895   90556
# 13  서대문구  321966  308437  13529   56785
# 14   마포구  376542  365570  10972   56582
# 15   양천구  442345  439219   3126   73522
# 16   강서구  573711  568287   5424   98659
# 17   구로구  417983  395183  22800   77259
# 18   금천구  242467  229307  13160   43772
# 19  영등포구  398999  376614  22385   66014
# 20   동작구  390377  380201  10176   68766
# 21   관악구  502628  487815  14813   83420
# 22   서초구  408979  404831   4148   63328
# ...

# %%
# 구별을 인덱스로 만들기
person.set_index('구별', inplace=True)
person
# Out:
#          인구수     내국인    외국인     고령자
# 구별
# 종로구   152212  141060  11152   28265
# 중구    131390  120963  10427   25353
# 용산구   232482  217756  14726   39478
# 성동구   287240  280240   7000   48238
# 광진구   350925  336801  14124   54854
# 동대문구  354884  337574  17310   65154
# 중랑구   389928  385003   4925   76116
# 성북구   441855  430100  11755   78427
# 강북구   296934  292762   4172   67056
# 도봉구   312858  310509   2349   68114
# 노원구   506989  502515   4474   93279
# 은평구   468766  464871   3895   90556
# 서대문구  321966  308437  13529   56785
# 마포구   376542  365570  10972   56582
# 양천구   442345  439219   3126   73522
# 강서구   573711  568287   5424   98659
# 구로구   417983  395183  22800   77259
# 금천구   242467  229307  13160   43772
# 영등포구  398999  376614  22385   66014
# 동작구   390377  380201  10176   68766
# 관악구   502628  487815  14813   83420
# 서초구   408979  404831   4148   63328
# 강남구   537817  532798   5019   83097
# 송파구   663704  658006   5698  105161
# 강동구   464027  459982   4045   79706

# %%
# 외국인 비율, 고령자 비율
person['외국인 비율'] = (person.외국인/person['인구수']*100).round(2)
person['고령자 비율'] = (person['고령자']/person['인구수']*100).round(2)
person
# Out:
#          인구수     내국인    외국인     고령자  외국인 비율  고령자 비율
# 구별
# 종로구   152212  141060  11152   28265    7.33   18.57
# 중구    131390  120963  10427   25353    7.94   19.30
# 용산구   232482  217756  14726   39478    6.33   16.98
# 성동구   287240  280240   7000   48238    2.44   16.79
# 광진구   350925  336801  14124   54854    4.02   15.63
# 동대문구  354884  337574  17310   65154    4.88   18.36
# 중랑구   389928  385003   4925   76116    1.26   19.52
# 성북구   441855  430100  11755   78427    2.66   17.75
# 강북구   296934  292762   4172   67056    1.41   22.58
# 도봉구   312858  310509   2349   68114    0.75   21.77
# 노원구   506989  502515   4474   93279    0.88   18.40
# 은평구   468766  464871   3895   90556    0.83   19.32
# 서대문구  321966  308437  13529   56785    4.20   17.64
# 마포구   376542  365570  10972   56582    2.91   15.03
# 양천구   442345  439219   3126   73522    0.71   16.62
# 강서구   573711  568287   5424   98659    0.95   17.20
# 구로구   417983  395183  22800   77259    5.45   18.48
# ...

# %% [markdown]
# ### 3.CCTV 데이터와 POP 데이터 합치기

# %%
df = pd.merge(cctv, person, left_index=True, right_index=True)
df
# Out:
#       CCTV댓수  최근증가율     인구수     내국인    외국인     고령자  외국인 비율  고령자 비율
# 종로구    10797  45.48  152212  141060  11152   28265    7.33   18.57
# 중구      9593  56.49  131390  120963  10427   25353    7.94   19.30
# 용산구    15775  44.27  232482  217756  14726   39478    6.33   16.98
# 성동구    19915  51.76  287240  280240   7000   48238    2.44   16.79
# 광진구    15082  58.72  350925  336801  14124   54854    4.02   15.63
# 동대문구   15111  47.68  354884  337574  17310   65154    4.88   18.36
# 중랑구    16762  63.32  389928  385003   4925   76116    1.26   19.52
# 성북구    20856  52.31  441855  430100  11755   78427    2.66   17.75
# 강북구    13585  62.43  296934  292762   4172   67056    1.41   22.58
# 도봉구     7501  62.09  312858  310509   2349   68114    0.75   21.77
# 노원구    13473  48.07  506989  502515   4474   93279    0.88   18.40
# 은평구    23293  48.75  468766  464871   3895   90556    0.83   19.32
# 서대문구   15538  51.60  321966  308437  13529   56785    4.20   17.64
# ...

# %%
df.shape
# Out:
# (25, 8)

# %%
df.index.name = '구별'
df
# Out:
#       CCTV댓수  최근증가율     인구수     내국인    외국인     고령자  외국인 비율  고령자 비율
# 구별
# 종로구    10797  45.48  152212  141060  11152   28265    7.33   18.57
# 중구      9593  56.49  131390  120963  10427   25353    7.94   19.30
# 용산구    15775  44.27  232482  217756  14726   39478    6.33   16.98
# 성동구    19915  51.76  287240  280240   7000   48238    2.44   16.79
# 광진구    15082  58.72  350925  336801  14124   54854    4.02   15.63
# 동대문구   15111  47.68  354884  337574  17310   65154    4.88   18.36
# 중랑구    16762  63.32  389928  385003   4925   76116    1.26   19.52
# 성북구    20856  52.31  441855  430100  11755   78427    2.66   17.75
# 강북구    13585  62.43  296934  292762   4172   67056    1.41   22.58
# 도봉구     7501  62.09  312858  310509   2349   68114    0.75   21.77
# 노원구    13473  48.07  506989  502515   4474   93279    0.88   18.40
# 은평구    23293  48.75  468766  464871   3895   90556    0.83   19.32
# 서대문구   15538  51.60  321966  308437  13529   56785    4.20   17.64
# ...
