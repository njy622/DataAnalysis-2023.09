# %% [markdown]
# ### OpenWeather API 2.5

# %%
import requests

# %%
with open('../static/keys/OpenweatherApiKey.txt') as file:
    weather_key = file.read()

# %%
base_url = 'https://api.openweathermap.org/data/2.5/onecall'
lat, lng = 37.5260, 126.8964
url = f'{base_url}?lat={lat}&lon={lng}&appid={weather_key}&units=metric&lang=kr'
result = requests.get(url).json()
result
# Out:
# {'lat': 37.526,
#  'lon': 126.8964,
#  'timezone': 'Asia/Seoul',
#  'timezone_offset': 32400,
#  'current': {'dt': 1695795740,
#   'sunrise': 1695763420,
#   'sunset': 1695806617,
#   'temp': 23.98,
#   'feels_like': 24.47,
#   'pressure': 1011,
#   'humidity': 78,
#   'dew_point': 19.91,
#   'uvi': 2.74,
#   'clouds': 75,
#   'visibility': 10000,
#   'wind_speed': 1.54,
#   'wind_deg': 300,
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': '튼구름',
#     'icon': '04d'}]},
#  'minutely': [{'dt': 1695795780, 'precipitation': 0},
#   {'dt': 1695795840, 'precipitation': 0},
#   {'dt': 1695795900, 'precipitation': 0},
#   {'dt': 1695795960, 'precipitation': 0},
#   {'dt': 1695796020, 'precipitation': 0},
#   {'dt': 1695796080, 'precipitation': 0},
#   {'dt': 1695796140, 'precipitation': 0},
#   {'dt': 1695796200, 'precipitation': 0},
#   {'dt': 1695796260, 'precipitation': 0},
#   {'dt': 1695796320, 'precipitation': 0},
#   {'dt': 1695796380, 'precipitation': 0},
#   {'dt': 1695796440, 'precipitation': 0},
#   {'dt': 1695796500, 'precipitation': 0},
#   {'dt': 1695796560, 'precipitation': 0},
#   {'dt': 1695796620, 'precipitation': 0},
#   {'dt': 1695796680, 'precipitation': 0},
#   {'dt': 1695796740, 'precipitation': 0},
#   {'dt': 1695796800, 'precipitation': 0},
#   {'dt': 1695796860, 'precipitation': 0},
#   {'dt': 1695796920, 'precipitation': 0},
#   {'dt': 1695796980, 'precipitation': 0},
#   {'dt': 1695797040, 'precipitation': 0},
#   {'dt': 1695797100, 'precipitation': 0},
#   {'dt': 1695797160, 'precipitation': 0},
#   {'dt': 1695797220, 'precipitation': 0},
#   {'dt': 1695797280, 'precipitation': 0},
#   {'dt': 1695797340, 'precipitation': 0},
#   {'dt': 1695797400, 'precipitation': 0},
#   {'dt': 1695797460, 'precipitation': 0},
#   {'dt': 1695797520, 'precipitation': 0},
#   {'dt': 1695797580, 'precipitation': 0},
#   {'dt': 1695797640, 'precipitation': 0},
#   {'dt': 1695797700, 'precipitation': 0},
#   {'dt': 1695797760, 'precipitation': 0},
#   {'dt': 1695797820, 'precipitation': 0},
#   {'dt': 1695797880, 'precipitation': 0},
#   {'dt': 1695797940, 'precipitation': 0},
#   {'dt': 1695798000, 'precipitation': 0},
#   {'dt': 1695798060, 'precipitation': 0},
#   {'dt': 1695798120, 'precipitation': 0},
#   {'dt': 1695798180, 'precipitation': 0},
#   {'dt': 1695798240, 'precipitation': 0},
#   {'dt': 1695798300, 'precipitation': 0},
#   {'dt': 1695798360, 'precipitation': 0},
#   {'dt': 1695798420, 'precipitation': 0},
#   {'dt': 1695798480, 'precipitation': 0},
#   {'dt': 1695798540, 'precipitation': 0},
#   {'dt': 1695798600, 'precipitation': 0},
#   {'dt': 1695798660, 'precipitation': 0},
#   {'dt': 1695798720, 'precipitation': 0},
#   {'dt': 1695798780, 'precipitation': 0},
#   {'dt': 1695798840, 'precipitation': 0},
#   {'dt': 1695798900, 'precipitation': 0},
#   {'dt': 1695798960, 'precipitation': 0},
#   {'dt': 1695799020, 'precipitation': 0},
#   {'dt': 1695799080, 'precipitation': 0},
#   {'dt': 1695799140, 'precipitation': 0},
#   {'dt': 1695799200, 'precipitation': 0},
#   {'dt': 1695799260, 'precipitation': 0},
#   {'dt': 1695799320, 'precipitation': 0},
#   {'dt': 1695799380, 'precipitation': 0}],
#  'hourly': [{'dt': 1695794400,
#    'temp': 23.98,
#    'feels_like': 24.47,
#    'pressure': 1011,
#    'humidity': 78,
#    'dew_point': 19.91,
#    'uvi': 2.74,
#    'clouds': 75,
#    'visibility': 10000,
#    'wind_speed': 0.96,
#    'wind_deg': 270,
#    'wind_gust': 1.56,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': '튼구름',
#      'icon': '04d'}],
#    'pop': 0.02},
#   {'dt': 1695798000,
#    'temp': 23.89,
#    'feels_like': 24.35,
#    'pressure': 1011,
#    'humidity': 77,
#    'dew_point': 19.61,
#    'uvi': 0.68,
#    'clouds': 74,
#    'visibility': 10000,
#    'wind_speed': 1.35,
#    'wind_deg': 268,
#    'wind_gust': 1.95,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': '튼구름',
#      'icon': '04d'}],
#    'pop': 0.05},
#   {'dt': 1695801600,
#    'temp': 23.7,
#    'feels_like': 24.11,
#    'pressure': 1011,
#    'humidity': 76,
#    'dew_point': 19.22,
#    'uvi': 0.24,
#    'clouds': 75,
#    'visibility': 10000,
#    'wind_speed': 1.74,
#    'wind_deg': 267,
#    'wind_gust': 2.46,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': '튼구름',
#      'icon': '04d'}],
#    'pop': 0.08},
#   {'dt': 1695805200,
#    'temp': 23.1,
#    'feels_like': 23.48,
#    'pressure': 1011,
#    'humidity': 77,
#    'dew_point': 18.85,
#    'uvi': 0,
#    'clouds': 76,
#    'visibility': 10000,
#    'wind_speed': 1.81,
#    'wind_deg': 260,
#    'wind_gust': 2.33,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': '튼구름',
#      'icon': '04d'}],
#    'pop': 0.08},
#   {'dt': 1695808800,
#    'temp': 22.48,
#    'feels_like': 22.82,
#    'pressure': 1011,
#    'humidity': 78,
#    'dew_point': 18.45,
#    'uvi': 0,
#    'clouds': 79,
#    'visibility': 10000,
#    'wind_speed': 1.94,
#    'wind_deg': 264,
#    'wind_gust': 2.76,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': '튼구름',
#      'icon': '04n'}],
#    'pop': 0.12},
#   {'dt': 1695812400,
#    'temp': 21.8,
#    'feels_like': 22.12,
#    'pressure': 1012,
#    'humidity': 80,
#    'dew_point': 17.96,
#    'uvi': 0,
#    'clouds': 81,
#    'visibility': 10000,
#    'wind_speed': 2.01,
#    'wind_deg': 266,
#    'wind_gust': 3.69,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': '튼구름',
#      'icon': '04n'}],
#    'pop': 0.1},
#   {'dt': 1695816000,
#    'temp': 21.5,
#    'feels_like': 21.85,
#    'pressure': 1012,
#    'humidity': 82,
#    'dew_point': 18.08,
#    'uvi': 0,
#    'clouds': 78,
#    'visibility': 10000,
#    'wind_speed': 1.55,
#    'wind_deg': 254,
#    'wind_gust': 2.41,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': '튼구름',
#      'icon': '04n'}],
#    'pop': 0.05},
#   {'dt': 1695819600,
#    'temp': 21.17,
#    'feels_like': 21.54,
#    'pressure': 1012,
#    'humidity': 84,
#    'dew_point': 18.24,
#    'uvi': 0,
#    'clouds': 33,
#    'visibility': 10000,
#    'wind_speed': 1.05,
#    'wind_deg': 233,
#    'wind_gust': 1.83,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': '구름조금',
#      'icon': '03n'}],
#    'pop': 0},
#   {'dt': 1695823200,
#    'temp': 20.9,
#    'feels_like': 21.29,
#    'pressure': 1012,
#    'humidity': 86,
#    'dew_point': 18.26,
#    'uvi': 0,
#    'clouds': 27,
#    'visibility': 10000,
#    'wind_speed': 1.18,
#    'wind_deg': 220,
#    'wind_gust': 2,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': '구름조금',
#      'icon': '03n'}],
#    'pop': 0},
#   {'dt': 1695826800,
#    'temp': 20.75,
#    'feels_like': 21.18,
#    'pressure': 1012,
#    'humidity': 88,
#    'dew_point': 18.37,
#    'uvi': 0,
#    'clouds': 45,
#    'visibility': 10000,
#    'wind_speed': 1.2,
#    'wind_deg': 201,
#    'wind_gust': 2.18,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': '구름조금',
#      'icon': '03n'}],
#    'pop': 0},
#   {'dt': 1695830400,
#    'temp': 20.9,
#    'feels_like': 21.32,
#    'pressure': 1012,
#    'humidity': 87,
#    'dew_point': 18.49,
#    'uvi': 0,
#    'clouds': 59,
#    'visibility': 10000,
#    'wind_speed': 1.02,
#    'wind_deg': 227,
#    'wind_gust': 2.41,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': '튼구름',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1695834000,
#    'temp': 20.56,
#    'feels_like': 21,
#    'pressure': 1012,
#    'humidity': 89,
#    'dew_point': 18.58,
#    'uvi': 0,
#    'clouds': 67,
#    'visibility': 10000,
#    'wind_speed': 0.86,
#    'wind_deg': 259,
#    'wind_gust': 2.33,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': '실 비',
#      'icon': '10n'}],
#    'pop': 0.24,
#    'rain': {'1h': 0.45}},
#   {'dt': 1695837600,
#    'temp': 20.56,
#    'feels_like': 21.02,
#    'pressure': 1012,
#    'humidity': 90,
#    'dew_point': 18.6,
#    'uvi': 0,
#    'clouds': 73,
#    'visibility': 10000,
#    'wind_speed': 0.63,
#    'wind_deg': 249,
#    'wind_gust': 1.93,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': '실 비',
#      'icon': '10n'}],
#    'pop': 0.28,
#    'rain': {'1h': 0.12}},
#   {'dt': 1695841200,
#    'temp': 20.33,
#    'feels_like': 20.79,
#    'pressure': 1012,
#    'humidity': 91,
#    'dew_point': 18.54,
#    'uvi': 0,
#    'clouds': 85,
#    'visibility': 10000,
#    'wind_speed': 1.43,
#    'wind_deg': 290,
#    'wind_gust': 2.41,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': '온흐림',
#      'icon': '04n'}],
#    'pop': 0.05},
#   {'dt': 1695844800,
#    'temp': 20,
#    'feels_like': 20.46,
#    'pressure': 1012,
#    'humidity': 92,
#    'dew_point': 18.36,
#    'uvi': 0,
#    'clouds': 58,
#    'visibility': 10000,
#    'wind_speed': 0.65,
#    'wind_deg': 294,
#    'wind_gust': 1,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': '튼구름',
#      'icon': '04n'}],
#    'pop': 0.13},
#   {'dt': 1695848400,
#    'temp': 19.78,
#    'feels_like': 20.22,
#    'pressure': 1013,
#    'humidity': 92,
#    'dew_point': 18.21,
#    'uvi': 0,
#    'clouds': 41,
#    'visibility': 10000,
#    'wind_speed': 1.32,
#    'wind_deg': 283,
#    'wind_gust': 1.73,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': '구름조금',
#      'icon': '03n'}],
#    'pop': 0.12},
#   {'dt': 1695852000,
#    'temp': 19.86,
#    'feels_like': 20.3,
#    'pressure': 1014,
#    'humidity': 92,
#    'dew_point': 18.2,
#    'uvi': 0,
#    'clouds': 32,
#    'visibility': 10000,
#    'wind_speed': 0.98,
#    'wind_deg': 297,
#    'wind_gust': 1.43,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': '구름조금',
#      'icon': '03d'}],
#    'pop': 0.09},
#   {'dt': 1695855600,
#    'temp': 20.79,
#    'feels_like': 21.17,
#    'pressure': 1014,
#    'humidity': 86,
#    'dew_point': 18.13,
#    'uvi': 0.52,
#    'clouds': 26,
#    'visibility': 10000,
#    'wind_speed': 0.88,
#    'wind_deg': 308,
#    'wind_gust': 1.61,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': '구름조금',
#      'icon': '03d'}],
#    'pop': 0.07},
#   {'dt': 1695859200,
#    'temp': 22.05,
#    'feels_like': 22.32,
#    'pressure': 1015,
#    'humidity': 77,
#    'dew_point': 17.62,
#    'uvi': 1.58,
#    'clouds': 22,
#    'visibility': 10000,
#    'wind_speed': 1.14,
#    'wind_deg': 302,
#    'wind_gust': 2.13,
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': '약간의 구름이 낀 하늘',
#      'icon': '02d'}],
#    'pop': 0.07},
#   {'dt': 1695862800,
#    'temp': 23.27,
#    'feels_like': 23.45,
#    'pressure': 1015,
#    'humidity': 69,
#    'dew_point': 17.04,
#    'uvi': 3.2,
#    'clouds': 1,
#    'visibility': 10000,
#    'wind_speed': 1.53,
#    'wind_deg': 301,
#    'wind_gust': 2.42,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': '맑음',
#      'icon': '01d'}],
#    'pop': 0},
#   {'dt': 1695866400,
#    'temp': 24.5,
#    'feels_like': 24.65,
#    'pressure': 1014,
#    'humidity': 63,
#    'dew_point': 16.73,
#    'uvi': 4.86,
#    'clouds': 1,
#    'visibility': 10000,
#    'wind_speed': 1.89,
#    'wind_deg': 299,
#    'wind_gust': 2.78,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': '맑음',
#      'icon': '01d'}],
#    'pop': 0},
#   {'dt': 1695870000,
#    'temp': 25.53,
#    'feels_like': 25.65,
#    'pressure': 1014,
#    'humidity': 58,
#    'dew_point': 16.33,
#    'uvi': 5.93,
#    'clouds': 0,
#    'visibility': 10000,
#    'wind_speed': 2.56,
#    'wind_deg': 278,
#    'wind_gust': 3.57,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': '맑음',
#      'icon': '01d'}],
#    'pop': 0},
#   {'dt': 1695873600,
#    'temp': 26.22,
#    'feels_like': 26.22,
#    'pressure': 1013,
#    'humidity': 54,
#    'dew_point': 16.03,
#    'uvi': 5.99,
#    'clouds': 0,
#    'visibility': 10000,
#    'wind_speed': 3.64,
#    'wind_deg': 273,
#    'wind_gust': 4.72,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': '맑음',
#      'icon': '01d'}],
#    'pop': 0},
#   {'dt': 1695877200,
#    'temp': 26.49,
#    'feels_like': 26.49,
#    'pressure': 1013,
#    'humidity': 52,
#    'dew_point': 15.56,
#    'uvi': 5.03,
#    'clouds': 0,
#    'visibility': 10000,
#    'wind_speed': 4.36,
#    'wind_deg': 273,
#    'wind_gust': 5.18,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': '맑음',
#      'icon': '01d'}],
#    'pop': 0},
#   {'dt': 1695880800,
#    'temp': 26.3,
#    'feels_like': 26.3,
#    'pressure': 1013,
#    'humidity': 51,
#    'dew_point': 15.13,
#    'uvi': 3.43,
#    'clouds': 0,
#    'visibility': 10000,
#    'wind_speed': 4.32,
#    'wind_deg': 265,
#    'wind_gust': 4.93,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': '맑음',
#      'icon': '01d'}],
#    'pop': 0},
#   {'dt': 1695884400,
#    'temp': 25.88,
#    'feels_like': 25.93,
#    'pressure': 1013,
#    'humidity': 54,
#    'dew_point': 15.49,
#    'uvi': 1.79,
#    'clouds': 0,
#    'visibility': 10000,
#    'wind_speed': 4.48,
#    'wind_deg': 264,
#    'wind_gust': 5.2,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': '맑음',
#      'icon': '01d'}],
#    'pop': 0},
#   {'dt': 1695888000,
#    'temp': 24.81,
#    'feels_like': 24.91,
#    'pressure': 1014,
#    'humidity': 60,
#    'dew_point': 16.27,
#    'uvi': 0.62,
#    'clouds': 0,
#    'visibility': 10000,
#    'wind_speed': 4.61,
#    'wind_deg': 263,
#    'wind_gust': 5.6,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': '맑음',
#      'icon': '01d'}],
#    'pop': 0},
#   {'dt': 1695891600,
#    'temp': 23.79,
#    'feels_like': 23.84,
#    'pressure': 1014,
#    'humidity': 62,
#    'dew_point': 15.9,
#    'uvi': 0,
#    'clouds': 0,
#    'visibility': 10000,
#    'wind_speed': 4.02,
#    'wind_deg': 261,
#    'wind_gust': 6.47,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': '맑음',
#      'icon': '01d'}],
#    'pop': 0},
#   {'dt': 1695895200,
#    'temp': 23.11,
#    'feels_like': 23.07,
#    'pressure': 1014,
#    'humidity': 61,
#    'dew_point': 15.07,
#    'uvi': 0,
#    'clouds': 0,
#    'visibility': 10000,
#    'wind_speed': 3.28,
#    'wind_deg': 278,
#    'wind_gust': 6.73,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': '맑음',
#      'icon': '01n'}],
#    'pop': 0},
#   {'dt': 1695898800,
#    'temp': 22.59,
#    'feels_like': 22.39,
#    'pressure': 1014,
#    'humidity': 57,
#    'dew_point': 13.42,
#    'uvi': 0,
#    'clouds': 1,
#    'visibility': 10000,
#    'wind_speed': 2.81,
#    'wind_deg': 316,
#    'wind_gust': 6.43,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': '맑음',
#      'icon': '01n'}],
#    'pop': 0},
#   {'dt': 1695902400,
#    'temp': 21.69,
#    'feels_like': 21.22,
#    'pressure': 1014,
#    'humidity': 50,
#    'dew_point': 10.78,
#    'uvi': 0,
#    'clouds': 6,
#    'visibility': 10000,
#    'wind_speed': 2.39,
#    'wind_deg': 316,
#    'wind_gust': 5.9,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': '맑음',
#      'icon': '01n'}],
#    'pop': 0},
#   {'dt': 1695906000,
#    'temp': 20.87,
#    'feels_like': 20.34,
#    'pressure': 1015,
#    'humidity': 51,
#    'dew_point': 10.2,
#    'uvi': 0,
#    'clouds': 59,
#    'visibility': 10000,
#    'wind_speed': 1.75,
#    'wind_deg': 308,
#    'wind_gust': 4.11,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': '튼구름',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1695909600,
#    'temp': 20.31,
#    'feels_like': 19.73,
#    'pressure': 1015,
#    'humidity': 51,
#    'dew_point': 9.74,
#    'uvi': 0,
#    'clouds': 75,
#    'visibility': 10000,
#    'wind_speed': 1.54,
#    'wind_deg': 316,
#    'wind_gust': 3.77,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': '튼구름',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1695913200,
#    'temp': 19.89,
#    'feels_like': 19.29,
#    'pressure': 1015,
#    'humidity': 52,
#    'dew_point': 9.46,
#    'uvi': 0,
#    'clouds': 83,
#    'visibility': 10000,
#    'wind_speed': 1.7,
#    'wind_deg': 313,
#    'wind_gust': 3.84,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': '튼구름',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1695916800,
#    'temp': 19.52,
#    'feels_like': 18.89,
#    'pressure': 1015,
#    'humidity': 52,
#    'dew_point': 9.24,
#    'uvi': 0,
#    'clouds': 87,
#    'visibility': 10000,
#    'wind_speed': 1.25,
#    'wind_deg': 305,
#    'wind_gust': 3.25,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': '온흐림',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1695920400,
#    'temp': 19.15,
#    'feels_like': 18.5,
#    'pressure': 1015,
#    'humidity': 53,
#    'dew_point': 9.07,
#    'uvi': 0,
#    'clouds': 90,
#    'visibility': 10000,
#    'wind_speed': 0.93,
#    'wind_deg': 295,
#    'wind_gust': 1.56,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': '온흐림',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1695924000,
#    'temp': 18.78,
#    'feels_like': 18.1,
#    'pressure': 1015,
#    'humidity': 53,
#    'dew_point': 8.92,
#    'uvi': 0,
#    'clouds': 91,
#    'visibility': 10000,
#    'wind_speed': 1.23,
#    'wind_deg': 290,
#    'wind_gust': 1.77,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': '온흐림',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1695927600,
#    'temp': 18.64,
#    'feels_like': 17.97,
#    'pressure': 1015,
#    'humidity': 54,
#    'dew_point': 8.86,
#    'uvi': 0,
#    'clouds': 99,
#    'visibility': 10000,
#    'wind_speed': 1.01,
#    'wind_deg': 253,
#    'wind_gust': 1.4,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': '온흐림',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1695931200,
#    'temp': 18.57,
#    'feels_like': 17.89,
#    'pressure': 1015,
#    'humidity': 54,
#    'dew_point': 8.92,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 0.88,
#    'wind_deg': 303,
#    'wind_gust': 1.41,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': '온흐림',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1695934800,
#    'temp': 18.56,
#    'feels_like': 17.88,
#    'pressure': 1015,
#    'humidity': 54,
#    'dew_point': 8.89,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 1.11,
#    'wind_deg': 303,
#    'wind_gust': 2.1,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': '온흐림',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1695938400,
#    'temp': 18.59,
#    'feels_like': 17.91,
#    'pressure': 1015,
#    'humidity': 54,
#    'dew_point': 9,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 1.16,
#    'wind_deg': 357,
#    'wind_gust': 2.41,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': '온흐림',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1695942000,
#    'temp': 19.06,
#    'feels_like': 18.38,
#    'pressure': 1016,
#    'humidity': 52,
#    'dew_point': 8.85,
#    'uvi': 0.43,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 0.71,
#    'wind_deg': 42,
#    'wind_gust': 1.39,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': '온흐림',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1695945600,
#    'temp': 20.07,
#    'feels_like': 19.39,
#    'pressure': 1016,
#    'humidity': 48,
#    'dew_point': 8.5,
#    'uvi': 1.31,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 0.22,
#    'wind_deg': 317,
#    'wind_gust': 0.99,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': '온흐림',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1695949200,
#    'temp': 21.7,
#    'feels_like': 21.02,
#    'pressure': 1016,
#    'humidity': 42,
#    'dew_point': 8.22,
#    'uvi': 3.08,
#    'clouds': 99,
#    'visibility': 10000,
#    'wind_speed': 0.79,
#    'wind_deg': 308,
#    'wind_gust': 1.02,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': '온흐림',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1695952800,
#    'temp': 22.84,
#    'feels_like': 22.17,
#    'pressure': 1015,
#    'humidity': 38,
#    'dew_point': 7.66,
#    'uvi': 4.7,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 1.33,
#    'wind_deg': 345,
#    'wind_gust': 1.69,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': '온흐림',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1695956400,
#    'temp': 24.27,
#    'feels_like': 23.61,
#    'pressure': 1015,
#    'humidity': 33,
#    'dew_point': 7.05,
#    'uvi': 5.74,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 0.69,
#    'wind_deg': 291,
#    'wind_gust': 0.99,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': '온흐림',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1695960000,
#    'temp': 24.97,
#    'feels_like': 24.33,
#    'pressure': 1014,
#    'humidity': 31,
#    'dew_point': 6.48,
#    'uvi': 5.65,
#    'clouds': 98,
#    'visibility': 10000,
#    'wind_speed': 1.64,
#    'wind_deg': 275,
#    'wind_gust': 1.66,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': '온흐림',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1695963600,
#    'temp': 25.28,
#    'feels_like': 24.65,
#    'pressure': 1014,
#    'humidity': 30,
#    'dew_point': 6.2,
#    'uvi': 4.75,
#    'clouds': 98,
#    'visibility': 10000,
#    'wind_speed': 2.35,
#    'wind_deg': 273,
#    'wind_gust': 2.33,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': '온흐림',
#      'icon': '04d'}],
#    'pop': 0}],
#  'daily': [{'dt': 1695783600,
#    'sunrise': 1695763420,
#    'sunset': 1695806617,
#    'moonrise': 1695803160,
#    'moonset': 1695752220,
#    'moon_phase': 0.41,
#    'temp': {'day': 22.15,
#     'min': 19.47,
#     'max': 23.98,
#     'night': 20.9,
#     'eve': 23.1,
#     'morn': 19.48},
#    'feels_like': {'day': 22.61, 'night': 21.29, 'eve': 23.48, 'morn': 19.96},
#    'pressure': 1012,
#    'humidity': 84,
#    'dew_point': 19.32,
#    'wind_speed': 2.01,
#    'wind_deg': 266,
#    'wind_gust': 3.69,
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': '보통 비',
#      'icon': '10d'}],
#    'clouds': 90,
#    'pop': 0.59,
#    'rain': 4.59,
#    'uvi': 4.78},
#   {'dt': 1695870000,
#    'sunrise': 1695849871,
#    'sunset': 1695892924,
#    'moonrise': 1695891300,
#    'moonset': 1695843180,
#    'moon_phase': 0.45,
#    'temp': {'day': 25.53,
#     'min': 19.78,
#     'max': 26.49,
#     'night': 20.31,
#     'eve': 23.79,
#     'morn': 19.78},
#    'feels_like': {'day': 25.65, 'night': 19.73, 'eve': 23.84, 'morn': 20.22},
#    'pressure': 1014,
#    'humidity': 58,
#    'dew_point': 16.33,
#    'wind_speed': 4.61,
#    'wind_deg': 263,
#    'wind_gust': 6.73,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': '실 비',
#      'icon': '10d'}],
#    'clouds': 0,
#    'pop': 0.28,
#    'rain': 0.57,
#    'uvi': 5.99},
#   {'dt': 1695956400,
#    'sunrise': 1695936322,
#    'sunset': 1695979232,
#    'moonrise': 1695979380,
#    'moonset': 1695934140,
#    'moon_phase': 0.5,
#    'temp': {'day': 24.27,
#     'min': 18.56,
#     'max': 25.28,
#     'night': 21.52,
#     'eve': 23.08,
#     'morn': 18.56},
#    'feels_like': {'day': 23.61, 'night': 20.95, 'eve': 22.49, 'morn': 17.88},
#    'pressure': 1015,
#    'humidity': 33,
#    'dew_point': 7.05,
#    'wind_speed': 3.69,
#    'wind_deg': 302,
#    'wind_gust': 4.41,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': '온흐림',
#      'icon': '04d'}],
#    'clouds': 100,
#    'pop': 0,
#    'uvi': 5.74},
#   {'dt': 1696042800,
#    'sunrise': 1696022773,
#    'sunset': 1696065539,
#    'moonrise': 1696067400,
#    'moonset': 1696024980,
#    'moon_phase': 0.53,
#    'temp': {'day': 24.6,
#     'min': 19.08,
#     'max': 24.6,
#     'night': 20.43,
#     'eve': 22.11,
#     'morn': 19.08},
#    'feels_like': {'day': 24.34, 'night': 20.33, 'eve': 22.02, 'morn': 18.43},
#    'pressure': 1012,
#    'humidity': 47,
#    'dew_point': 12.51,
#    'wind_speed': 5.87,
#    'wind_deg': 264,
#    'wind_gust': 7.36,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': '실 비',
#      'icon': '10d'}],
#    'clouds': 37,
#    'pop': 0.24,
#    'rain': 0.12,
#    'uvi': 5.52},
#   {'dt': 1696129200,
#    'sunrise': 1696109224,
#    'sunset': 1696151847,
#    'moonrise': 1696155600,
#    'moonset': 1696115760,
#    'moon_phase': 0.56,
#    'temp': {'day': 21.51,
#     'min': 16.56,
#     'max': 22.52,
#     'night': 18.63,
#     'eve': 20.27,
#     'morn': 16.56},
#    'feels_like': {'day': 20.63, 'night': 17.65, 'eve': 19.34, 'morn': 15.84},
#    'pressure': 1014,
#    'humidity': 35,
#    'dew_point': 5.11,
#    'wind_speed': 6.69,
#    'wind_deg': 332,
#    'wind_gust': 9.66,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': '맑음',
#      'icon': '01d'}],
#    'clouds': 0,
#    'pop': 0,
#    'uvi': 4.87},
#   {'dt': 1696215600,
#    'sunrise': 1696195676,
#    'sunset': 1696238155,
#    'moonrise': 1696243920,
#    'moonset': 1696206540,
#    'moon_phase': 0.6,
#    'temp': {'day': 21.59,
#     'min': 14.77,
#     'max': 22.89,
#     'night': 19.09,
#     'eve': 21.12,
#     'morn': 14.77},
#    'feels_like': {'day': 20.56, 'night': 18.13, 'eve': 20.12, 'morn': 13.74},
#    'pressure': 1017,
#    'humidity': 29,
#    'dew_point': 2.76,
#    'wind_speed': 3.22,
#    'wind_deg': 327,
#    'wind_gust': 5.19,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': '맑음',
#      'icon': '01d'}],
#    'clouds': 0,
#    'pop': 0,
#    'uvi': 5},
#   {'dt': 1696302000,
#    'sunrise': 1696282127,
#    'sunset': 1696324464,
#    'moonrise': 1696332480,
#    'moonset': 1696297200,
#    'moon_phase': 0.64,
#    'temp': {'day': 21.48,
#     'min': 16.15,
#     'max': 21.48,
#     'night': 19.67,
#     'eve': 20.28,
#     'morn': 16.15},
#    'feels_like': {'day': 20.65, 'night': 18.87, 'eve': 19.36, 'morn': 15.23},
#    'pressure': 1019,
#    'humidity': 37,
#    'dew_point': 5.95,
#    'wind_speed': 1.94,
#    'wind_deg': 161,
#    'wind_gust': 3.97,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': '온흐림',
#      'icon': '04d'}],
#    'clouds': 100,
#    'pop': 0,
#    'uvi': 5},
#   {'dt': 1696388400,
#    'sunrise': 1696368580,
#    'sunset': 1696410773,
#    'moonrise': 1696421520,
#    'moonset': 1696387800,
#    'moon_phase': 0.67,
#    'temp': {'day': 20.28,
#     'min': 16.71,
#     'max': 21.49,
#     'night': 16.71,
#     'eve': 18.8,
#     'morn': 18.68},
#    'feels_like': {'day': 20.37, 'night': 15.74, 'eve': 18.2, 'morn': 18.41},
#    'pressure': 1012,
#    'humidity': 77,
#    'dew_point': 15.94,
#    'wind_speed': 6.87,
#    'wind_deg': 257,
#    'wind_gust': 10.83,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': '실 비',
#      'icon': '10d'}],
#    'clouds': 100,
#    'pop': 0.99,
#    'rain': 2.64,
#    'uvi': 5}]}

# %%
result['current'].keys()
# Out:
# dict_keys(['dt', 'sunrise', 'sunset', 'temp', 'feels_like', 'pressure', 'humidity', 'dew_point', 'uvi', 'clouds', 'visibility', 'wind_speed', 'wind_deg', 'weather'])

# %%
temp=result['current']['temp']
temp
# Out:
# 23.98

# %%
result['current']['weather']
# Out:
# [{'id': 803, 'main': 'Clouds', 'description': '튼구름', 'icon': '04d'}]

# %%
desc = result['current']['weather'][0]['description']
desc
# Out:
# '튼구름'

# %%
icon_code = result['current']['weather'][0]['icon']
icon_url = f'http://api.openweathermap.org/img/w/{icon_code}.png'

# %%
import urllib.request
from PIL import Image
import matplotlib.pylab as plt
urllib.request.urlretrieve(icon_url, '../static/img/icon.png')
img = Image.open('../static/img/icon.png')
plt.imshow(img), plt.axis('off');

# %%
html = f'''<img src="{icon_url}" height="32"><strong>{desc}</strong>
            온도: <strong>{temp:.1f}</strong>&#8451'''                  # &#8451 섭씨 도씨 의미
html
# Out:
# '<img src="http://api.openweathermap.org/img/w/04d.png" height="32"><strong>튼구름</strong>\n            온도: <strong>24.0</strong>&#8451'
